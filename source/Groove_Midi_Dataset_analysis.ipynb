# %% [markdown]
# # Download Groove MIDI Dataset

# %%
# !gdown 1TVJgOECJ-f_a1AK8HNfB9GDXxY0ssQcr
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TVJgOECJ-f_a1AK8HNfB9GDXxY0ssQcr
# To: /content/groove-v1.0.0-midionly.zip
# 100% 3.26M/3.26M [00:00<00:00, 207MB/s]

# %% [markdown]
# # Unzip & Check dataset

# %%
import zipfile

# %%
#zip파일 압축해제
zipfile.ZipFile('/content/groove-v1.0.0-midionly.zip').extractall()

# %%
import pandas as pd
df = pd.read_csv('/content/groove/info.csv')
df = pd.DataFrame(df)
df.head(10)
# Out:
#     drummer                session                        id           style  \
# 0  drummer1  drummer1/eval_session   drummer1/eval_session/1    funk/groove1
# 1  drummer1  drummer1/eval_session  drummer1/eval_session/10   soul/groove10
# 2  drummer1  drummer1/eval_session   drummer1/eval_session/2    funk/groove2
# 3  drummer1  drummer1/eval_session   drummer1/eval_session/3    soul/groove3
# 4  drummer1  drummer1/eval_session   drummer1/eval_session/4    soul/groove4
# 5  drummer1  drummer1/eval_session   drummer1/eval_session/5    funk/groove5
# 6  drummer1  drummer1/eval_session   drummer1/eval_session/6  hiphop/groove6
# 7  drummer1  drummer1/eval_session   drummer1/eval_session/7     pop/groove7
# 8  drummer1  drummer1/eval_session   drummer1/eval_session/8    rock/groove8
# 9  drummer1  drummer1/eval_session   drummer1/eval_session/9    soul/groove9
#
#    bpm beat_type time_signature  \
# 0  138      beat            4-4
# 1  102      beat            4-4
# ...

# %%
len(df)
# Out:
# 1150

# %% [markdown]
# ## Check style

# %%
# Check genre
df['style'].unique()
# Out:
# array(['funk/groove1', 'soul/groove10', 'funk/groove2', 'soul/groove3',
#        'soul/groove4', 'funk/groove5', 'hiphop/groove6', 'pop/groove7',
#        'rock/groove8', 'soul/groove9', 'funk', 'jazz/funk',
#        'neworleans/secondline', 'dance/disco', 'funk/fast',
#        'latin/brazilian-baiao', 'afrocuban', 'reggae', 'reggae/slow',
#        'rock/halftime', 'funk/purdieshuffle', 'latin/samba', 'jazz',
#        'rock/shuffle', 'jazz/mediumfast', 'jazz/fast', 'latin/reggaeton',
#        'dance/breakbeat', 'neworleans/funk', 'latin/chacarera', 'country',
#        'funk/rock', 'rock/prog', 'afrocuban/bembe', 'gospel',
#        'afrocuban/rhumba', 'rock', 'punk', 'jazz/march', 'rock/folk',
#        'afrobeat', 'latin/bomba', 'afrocuban/calypso', 'jazz/swing',
#        'rock/rockabilly', 'jazz/linear', 'hiphop', 'jazz/klezmer',
#        'latin/brazilian', 'blues/shuffle', 'latin/merengue',
#        'latin/brazilian-bossa', 'latin/brazilian-sambareggae',
# ...

# %%
genre = ['funk','soul','hiphop','pop','rock','jazz','neworleans','dance','latin','afrocuban','reggae','country','gospel','punk','afrobeat','blues','middleeastern','highlife']

# %%
len(genre)
# Out:
# 18

# %% [markdown]
# funk

# %%
funk = df[df['style'.split('/')[0]] == 'funk']
funk
# Out:
#        drummer            session                     id style  bpm beat_type  \
# 10    drummer1  drummer1/session1    drummer1/session1/1  funk   80      beat
# 14    drummer1  drummer1/session1  drummer1/session1/102  funk   95      beat
# 15    drummer1  drummer1/session1  drummer1/session1/103  funk   95      fill
# 16    drummer1  drummer1/session1  drummer1/session1/104  funk   95      fill
# 17    drummer1  drummer1/session1  drummer1/session1/105  funk   95      fill
# ...        ...                ...                    ...   ...  ...       ...
# 1068  drummer8  drummer8/session2   drummer8/session2/15  funk   95      beat
# 1069  drummer8  drummer8/session2   drummer8/session2/16  funk   95      beat
# 1073  drummer8  drummer8/session2    drummer8/session2/2  funk   92      beat
# 1099  drummer8  drummer8/session2    drummer8/session2/5  funk   91      beat
# 1100  drummer8  drummer8/session2    drummer8/session2/6  funk   91      beat
#
# ...

# %% [markdown]
# soul

# %%
soul = df[df['style'.split('/')[0]] == 'soul']
soul
# Out:
#       drummer            session                     id style  bpm beat_type  \
# 645  drummer5  drummer5/session2   drummer5/session2/11  soul   96      beat
# 900  drummer7  drummer7/session3  drummer7/session3/130  soul  105      beat
# 901  drummer7  drummer7/session3  drummer7/session3/131  soul  105      beat
# 902  drummer7  drummer7/session3  drummer7/session3/132  soul  105      beat
# 903  drummer7  drummer7/session3  drummer7/session3/133  soul  105      beat
# 904  drummer7  drummer7/session3  drummer7/session3/134  soul  105      fill
# 905  drummer7  drummer7/session3  drummer7/session3/135  soul  105      fill
# 906  drummer7  drummer7/session3  drummer7/session3/136  soul  105      fill
# 907  drummer7  drummer7/session3  drummer7/session3/137  soul  105      fill
# 908  drummer7  drummer7/session3  drummer7/session3/138  soul  105      fill
# 909  drummer7  drummer7/session3  drummer7/session3/139  soul  105      fill
# ...

# %% [markdown]
# hiphop

# %%
hiphop = df[df['style'.split('/')[0]] == 'hiphop']
hiphop
# Out:
#        drummer            session                    id   style  bpm  \
# 573   drummer3  drummer3/session2  drummer3/session2/25  hiphop   92
# 574   drummer3  drummer3/session2  drummer3/session2/26  hiphop   92
# 580   drummer3  drummer3/session2  drummer3/session2/31  hiphop   92
# 581   drummer3  drummer3/session2  drummer3/session2/32  hiphop   92
# 582   drummer3  drummer3/session2  drummer3/session2/33  hiphop   92
# ...        ...                ...                   ...     ...  ...
# 1055  drummer8  drummer8/session1   drummer8/session1/3  hiphop   90
# 1056  drummer8  drummer8/session1   drummer8/session1/4  hiphop   90
# 1057  drummer8  drummer8/session1   drummer8/session1/5  hiphop   90
# 1063  drummer8  drummer8/session2  drummer8/session2/10  hiphop   86
# 1103  drummer8  drummer8/session2   drummer8/session2/9  hiphop   86
#
#      beat_type time_signature                                midi_filename  \
# ...

# %% [markdown]
# pop

# %%
pop = df[df['style'.split('/')[0]] == 'pop']
pop
# Out:
#       drummer            session                     id style  bpm beat_type  \
# 734  drummer7  drummer7/session2  drummer7/session2/100   pop  142      beat
# 735  drummer7  drummer7/session2  drummer7/session2/101   pop  142      beat
# 736  drummer7  drummer7/session2  drummer7/session2/102   pop  132      beat
# 737  drummer7  drummer7/session2  drummer7/session2/103   pop  132      beat
# 738  drummer7  drummer7/session2  drummer7/session2/104   pop  132      beat
# 739  drummer7  drummer7/session2  drummer7/session2/105   pop  132      beat
# 861  drummer7  drummer7/session2   drummer7/session2/96   pop  142      beat
# 862  drummer7  drummer7/session2   drummer7/session2/97   pop  142      beat
# 863  drummer7  drummer7/session2   drummer7/session2/98   pop  142      fill
# 864  drummer7  drummer7/session2   drummer7/session2/99   pop  142      fill
#
#     time_signature                               midi_filename  \
# ...

# %% [markdown]
# rock

# %%
rock = df[df['style'.split('/')[0]] == 'rock']
rock
# Out:
#        drummer            session                     id style  bpm beat_type  \
# 368   drummer1  drummer1/session2  drummer1/session2/180  rock   50      beat
# 369   drummer1  drummer1/session2  drummer1/session2/181  rock  115      beat
# 370   drummer1  drummer1/session2  drummer1/session2/182  rock  115      fill
# 371   drummer1  drummer1/session2  drummer1/session2/183  rock  115      fill
# 372   drummer1  drummer1/session2  drummer1/session2/184  rock  115      fill
# ...        ...                ...                    ...   ...  ...       ...
# 1145  drummer2  drummer2/session2   drummer2/session2/11  rock  130      beat
# 1146  drummer2  drummer2/session2   drummer2/session2/12  rock  130      beat
# 1147  drummer2  drummer2/session2   drummer2/session2/13  rock  130      beat
# 1148  drummer2  drummer2/session2   drummer2/session2/14  rock  130      beat
# 1149  drummer2  drummer2/session2   drummer2/session2/15  rock  130      beat
#
# ...

# %% [markdown]
# jazz

# %%
jazz = df[df['style'.split('/')[0]] == 'jazz']
jazz
# Out:
#       drummer            session                    id style  bpm beat_type  \
# 220  drummer1  drummer1/session1  drummer1/session1/47  jazz  102      beat
# 221  drummer1  drummer1/session1  drummer1/session1/48  jazz   93      beat
# 222  drummer1  drummer1/session1  drummer1/session1/49  jazz  125      beat
# 224  drummer1  drummer1/session1  drummer1/session1/50  jazz  125      beat
# 226  drummer1  drummer1/session1  drummer1/session1/52  jazz  125      beat
# 227  drummer1  drummer1/session1  drummer1/session1/53  jazz  125      fill
# 228  drummer1  drummer1/session1  drummer1/session1/54  jazz  125      fill
# 229  drummer1  drummer1/session1  drummer1/session1/55  jazz  125      fill
# 230  drummer1  drummer1/session1  drummer1/session1/56  jazz  125      fill
# 231  drummer1  drummer1/session1  drummer1/session1/57  jazz  125      fill
# 232  drummer1  drummer1/session1  drummer1/session1/58  jazz  125      fill
# ...

# %% [markdown]
# reggae

# %%
reggae = df[df['style'.split('/')[0]] == 'reggae']
reggae
# Out:
#       drummer            session                     id   style  bpm  \
# 104  drummer1  drummer1/session1  drummer1/session1/184  reggae   78
# 105  drummer1  drummer1/session1  drummer1/session1/185  reggae   78
# 106  drummer1  drummer1/session1  drummer1/session1/186  reggae   78
# 107  drummer1  drummer1/session1  drummer1/session1/187  reggae   78
# 108  drummer1  drummer1/session1  drummer1/session1/188  reggae   78
# 109  drummer1  drummer1/session1  drummer1/session1/189  reggae   78
# 111  drummer1  drummer1/session1  drummer1/session1/190  reggae   78
# 112  drummer1  drummer1/session1  drummer1/session1/191  reggae   78
# 113  drummer1  drummer1/session1  drummer1/session1/192  reggae   78
# 114  drummer1  drummer1/session1  drummer1/session1/193  reggae   78
# 115  drummer1  drummer1/session1  drummer1/session1/194  reggae   78
# 116  drummer1  drummer1/session1  drummer1/session1/195  reggae   78
# 117  drummer1  drummer1/session1  drummer1/session1/196  reggae   78
# ...

# %% [markdown]
# country

# %%
country = df[df['style'.split('/')[0]] == 'country']
country
# Out:
#       drummer            session                    id    style  bpm  \
# 279  drummer1  drummer1/session2  drummer1/session2/10  country  114
# 290  drummer1  drummer1/session2  drummer1/session2/11  country  114
# 301  drummer1  drummer1/session2  drummer1/session2/12  country  114
# 312  drummer1  drummer1/session2  drummer1/session2/13  country  114
# 323  drummer1  drummer1/session2  drummer1/session2/14  country  114
# 334  drummer1  drummer1/session2  drummer1/session2/15  country  114
# 345  drummer1  drummer1/session2  drummer1/session2/16  country  114
# 356  drummer1  drummer1/session2  drummer1/session2/17  country  114
# 367  drummer1  drummer1/session2  drummer1/session2/18  country  114
# 378  drummer1  drummer1/session2  drummer1/session2/19  country  114
# 389  drummer1  drummer1/session2  drummer1/session2/20  country  114
# 390  drummer1  drummer1/session2  drummer1/session2/21  country  114
# 391  drummer1  drummer1/session2  drummer1/session2/22  country  114
# ...

# %% [markdown]
# puck

# %%
punk = df[df['style'.split('/')[0]] == 'punk']
punk
# Out:
#       drummer            session                    id style  bpm beat_type  \
# 402  drummer1  drummer1/session2  drummer1/session2/32  punk  140      beat
# 403  drummer1  drummer1/session2  drummer1/session2/33  punk  128      beat
# 404  drummer1  drummer1/session2  drummer1/session2/34  punk  128      beat
# 405  drummer1  drummer1/session2  drummer1/session2/35  punk  128      beat
# 406  drummer1  drummer1/session2  drummer1/session2/36  punk  128      beat
# 407  drummer1  drummer1/session2  drummer1/session2/37  punk  128      beat
# 408  drummer1  drummer1/session2  drummer1/session2/38  punk  128      fill
# 409  drummer1  drummer1/session2  drummer1/session2/39  punk  128      fill
# 411  drummer1  drummer1/session2  drummer1/session2/40  punk  128      fill
# 412  drummer1  drummer1/session2  drummer1/session2/41  punk  128      fill
# 413  drummer1  drummer1/session2  drummer1/session2/42  punk  128      fill
# ...

# %% [markdown]
# ## Check duration

# %%
df['duration']
# Out:
# 0       27.872308
# 1       37.691158
# 2       36.351218
# 3       44.716543
# 4       47.987500
#           ...
# 1145     1.909613
# 1146     1.808652
# 1147     1.864421
# 1148     1.875960
# 1149     3.714419
# Name: duration, Length: 1150, dtype: float64

# %%
# 합계
sum(df['duration'])
# Out:
# 48895.031629000005

# %%
# 최소값
min(df['duration'])
# Out:
# 0.679898

# %%
# 최대값
max(df['duration'])
# Out:
# 1394.173889

# %%
# 평균
sum(df['duration'])/len(df['duration'])
# Out:
# 42.51741880782609

# %%
# 1bar = 2s, 4초 이상 모으기 

over_2bar = df[df['duration'.split('.')[0]] >= 4]

# %%
over_2bar
# Out:
#        drummer                session                        id  \
# 0     drummer1  drummer1/eval_session   drummer1/eval_session/1
# 1     drummer1  drummer1/eval_session  drummer1/eval_session/10
# 2     drummer1  drummer1/eval_session   drummer1/eval_session/2
# 3     drummer1  drummer1/eval_session   drummer1/eval_session/3
# 4     drummer1  drummer1/eval_session   drummer1/eval_session/4
# ...        ...                    ...                       ...
# 1138  drummer2      drummer2/session2       drummer2/session2/4
# 1140  drummer2      drummer2/session2       drummer2/session2/6
# 1141  drummer2      drummer2/session2       drummer2/session2/7
# 1142  drummer2      drummer2/session2       drummer2/session2/8
# 1143  drummer2      drummer2/session2       drummer2/session2/9
#
#               style  bpm beat_type time_signature  \
# 0      funk/groove1  138      beat            4-4
# 1     soul/groove10  102      beat            4-4
# ...

# %%
len(over_2bar)
# Out:
# 557
